# %% [markdown]
# ## Grab Sample of Data

# %%
import xml.etree.ElementTree as ET  # Use cElementTree or lxml if too slow
import random

OSM_FILE = "map.osm"  # Replace this with your osm file
SAMPLE_FILE = "sample.osm"

# %%
k_range = [5,7] # Parameter: take every k-th top level element, where k is a random number between the two numbers given

def get_element(osm_file, tags=('node', 'way', 'relation')):
    """Yield element if it is the right type of tag

    Reference:
    http://stackoverflow.com/questions/3095434/inserting-newlines-in-xml-file-generated-via-xml-etree-elementtree-in-python
    """
    context = iter(ET.iterparse(osm_file, events=('start', 'end')))
    _, root = next(context)
    for event, elem in context:
        if event == 'end' and elem.tag in tags:
            yield elem
            root.clear()


with open(SAMPLE_FILE, 'wb') as output:
    output.write('<?xml version="1.0" encoding="UTF-8"?>\n'.encode())
    output.write('<osm>\n  '.encode())

    # Write every kth top level element
    for i, element in enumerate(get_element(OSM_FILE)):
        if i % random.randint(k_range[0], k_range[1]) == 0:
            output.write(ET.tostring(element, encoding='utf-8'))

    output.write('</osm>'.encode())

# %% [markdown]
# ## Audit Data

# %%
import audit

audit.audit(OSM_FILE, False)

# %% [markdown]
# ## Clean Data

# %%
import clean

clean.process_map(OSM_FILE, validate=True)

# %% [markdown]
# ## Import into SQL Database

# %%
import csv, sqlite3, pprint
from io import TextIOWrapper

con = sqlite3.connect("osm.db")
con.row_factory = sqlite3.Row
cur = con.cursor()
cur.execute("DROP TABLE IF EXISTS nodes")
cur.execute("DROP TABLE IF EXISTS nodes_tags")
cur.execute("DROP TABLE IF EXISTS ways")
cur.execute("DROP TABLE IF EXISTS ways_tags")
cur.execute("DROP TABLE IF EXISTS ways_nodes")
cur.executescript(open("schema.sql", "r").read())

import csv_to_sql

csv_to_sql.import_csv_files(['ways_tags', 'nodes', 'nodes_tags', 'ways', 'ways_nodes'], cur, True)
# Out:
# Sample of records from ways_tags
# [{'id': 11303991, 'key': 'natural', 'type': 'regular', 'value': 'coastline'},
#  {'id': 11303991, 'key': 'place', 'type': 'regular', 'value': 'islet'},
#  {'id': 11303991, 'key': 'source', 'type': 'regular', 'value': 'Bing'},
#  {'id': 11304451, 'key': 'natural', 'type': 'regular', 'value': 'coastline'},
#  {'id': 11304451, 'key': 'source', 'type': 'regular', 'value': 'Yahoo'}]
#
#
# Sample of records from nodes
# [{'changeset': 12737735,
#   'id': 100428663,
#   'lat': -3.7544864,
#   'lon': -38.4874113,
#   'timestamp': '2012-08-15T14:26:53Z',
#   'uid': 804310,
#   'user': 'Valentino Pinna',
#   'version': 2},
#  {'changeset': 46201793,
#   'id': 100429090,
#   'lat': -3.9356392,
#   'lon': -38.3037261,
#   'timestamp': '2017-02-18T20:48:54Z',
#   'uid': 612405,
#   'user': 'Narcélio de Sá',
#   'version': 3},
#  {'changeset': 10818383,
#   'id': 100429099,
#   'lat': -3.695213,
#   'lon': -38.6172759,
#   'timestamp': '2012-02-28T12:53:29Z',
#   'uid': 145275,
#   'user': 'Paper_',
#   'version': 2},
#  {'changeset': 23204765,
#   'id': 100429507,
#   'lat': -3.7173614,
#   'lon': -38.5223213,
#   'timestamp': '2014-06-27T02:56:38Z',
#   'uid': 612405,
#   'user': 'Narcélio de Sá',
#   'version': 8},
#  {'changeset': 569903,
#   'id': 100430485,
#   'lat': -3.8231491,
#   'lon': -38.4017816,
#   'timestamp': '2008-12-22T23:01:40Z',
#   'uid': 1596,
#   'user': 'Claudomiro',
#   'version': 5}]
#
#
# Sample of records from nodes_tags
# [{'id': 210738427,
#   'key': 'flag',
#   'type': 'regular',
#   'value': 'http://upload.wikimedia.org/wikipedia/commons/3/38/Bandeira_de_Fortaleza.svg'},
#  {'id': 210738427, 'key': 'is_in', 'type': 'regular', 'value': 'Ceará,Brazil'},
#  {'id': 210738427,
#   'key': 'continent',
#   'type': 'is_in',
#   'value': 'South America'},
#  {'id': 210738427, 'key': 'country', 'type': 'is_in', 'value': 'Brazil'},
#  {'id': 210738427, 'key': 'country_code', 'type': 'is_in', 'value': 'BR'}]
#
#
# Sample of records from ways
# [{'changeset': 12571418,
#   'id': 11303991,
#   'timestamp': '2012-08-01T08:57:51Z',
#   'uid': 534149,
#   'user': 'lurlrlrl',
#   'version': '4'},
#  {'changeset': 46201793,
#   'id': 11304451,
#   'timestamp': '2017-02-18T20:48:55Z',
#   'uid': 612405,
#   'user': 'Narcélio de Sá',
#   'version': '4'},
#  {'changeset': 10818383,
#   'id': 11304710,
#   'timestamp': '2012-02-28T12:53:24Z',
#   'uid': 145275,
#   'user': 'Paper_',
#   'version': '3'},
#  {'changeset': 11374081,
#   'id': 11304791,
#   'timestamp': '2012-04-21T14:07:54Z',
#   'uid': 149876,
#   'user': 'dbusse',
#   'version': '4'},
#  {'changeset': 46215504,
#   'id': 11305180,
#   'timestamp': '2017-02-19T13:21:38Z',
#   'uid': 612405,
#   'user': 'Narcélio de Sá',
#   'version': '16'}]
#
#
# Sample of records from ways_nodes
# [{'id': 11303991, 'node_id': 100479476, 'position': 0},
#  {'id': 11303991, 'node_id': 100448482, 'position': 1},
#  {'id': 11303991, 'node_id': 100471073, 'position': 2},
#  {'id': 11303991, 'node_id': 1651470099, 'position': 3},
#  {'id': 11303991, 'node_id': 1651470118, 'position': 4}]

# %% [markdown]
# ## Explore Database

# %%
# method for simplifying SQLite queries to database
# runs query, then outputs each record as a dict object, by default
def sql_query(syntax, output=True):
    cur.execute(syntax)
    if output == True:
        pprint.pprint([dict(i) for i in cur.fetchall()])

# number of unique users
sql_query("""
    SELECT COUNT(*) as users_count
    FROM (
        SELECT uid
        FROM nodes
        UNION
        SELECT uid
        FROM ways
    )
""")
# Out:
# [{'users_count': 457}]

# %%
# number of nodes
sql_query("""
    SELECT COUNT(*) as nodes_count
    FROM nodes
""")
# Out:
# [{'nodes_count': 210897}]

# %%
# number of ways
sql_query("""
    SELECT COUNT(*) as ways_count
    FROM ways
""")
# Out:
# [{'ways_count': 41542}]

# %%
# top ten nodes tags
sql_query("""
    SELECT COUNT(*) as count, key as node_key
    FROM nodes_tags
    GROUP BY key
    ORDER BY count DESC
    LIMIT 10
""")
# Out:
# [{'count': 10108, 'node_key': 'natural'},
#  {'count': 3453, 'node_key': 'name'},
#  {'count': 2904, 'node_key': 'source'},
#  {'count': 2569, 'node_key': 'power'},
#  {'count': 2457, 'node_key': 'street'},
#  {'count': 2350, 'node_key': 'housenumber'},
#  {'count': 2333, 'node_key': 'city'},
#  {'count': 2269, 'node_key': 'subur'},
#  {'count': 2141, 'node_key': 'highway'},
#  {'count': 1380, 'node_key': 'amenity'}]

# %%
# top ten ways tags
sql_query("""
    SELECT COUNT(*) as count, key
    FROM ways_tags
    GROUP BY key
    ORDER BY count DESC
    LIMIT 10
""")
# Out:
# [{'count': 27183, 'key': 'highway'},
#  {'count': 18062, 'key': 'name'},
#  {'count': 7975, 'key': 'building'},
#  {'count': 5147, 'key': 'oneway'},
#  {'count': 2409, 'key': 'levels'},
#  {'count': 1611, 'key': 'landuse'},
#  {'count': 1560, 'key': 'city'},
#  {'count': 1421, 'key': 'street'},
#  {'count': 1386, 'key': 'material'},
#  {'count': 1320, 'key': 'subur'}]

# %%
# top ten users by number of posts
sql_query("""
    SELECT user, uid, COUNT(*) as num
    FROM (SELECT user, uid FROM nodes UNION ALL SELECT user, uid FROM ways)
    GROUP BY uid
    ORDER BY num DESC
    LIMIT 10
""")
# Out:
# [{'num': 71931, 'uid': 612405, 'user': 'Narcélio de Sá'},
#  {'num': 29700, 'uid': 1657554, 'user': 'anderson stella'},
#  {'num': 13650, 'uid': 2507488, 'user': 'victorquaresma'},
#  {'num': 9945, 'uid': 1717892, 'user': 'Daniel de Góes Nepomuceno'},
#  {'num': 9012, 'uid': 510836, 'user': 'Rub21'},
#  {'num': 8819, 'uid': 1856060, 'user': 'patodiez'},
#  {'num': 8775, 'uid': 4393426, 'user': 'Jakson Aquino'},
#  {'num': 6835,
#   'uid': 1780702,
#   'user': 'Victor Hugo Pereira Soares de Joinville Moura'},
#  {'num': 5595, 'uid': 149876, 'user': 'dbusse'},
#  {'num': 4982, 'uid': 2889318, 'user': 'elias lopes'}]

# %%
# top ten neighborhoods in terms of number of nodes and ways tags
sql_query("""
    SELECT COUNT(*) as count, value as neighborhood
    FROM (SELECT * FROM nodes_tags WHERE key = 'subur' UNION ALL SELECT * FROM ways_tags WHERE key = 'subur')
    GROUP BY neighborhood
    ORDER BY count DESC
""")
# Out:
# [{'count': 719, 'neighborhood': 'Parque Albano'},
#  {'count': 451, 'neighborhood': 'Montese'},
#  {'count': 218, 'neighborhood': 'Prefeito José Walter'},
#  {'count': 171, 'neighborhood': 'Damas'},
#  {'count': 169, 'neighborhood': 'Conjunto Ceará'},
#  {'count': 149, 'neighborhood': 'Parangaba'},
#  {'count': 134, 'neighborhood': 'Vila União'},
#  {'count': 128, 'neighborhood': 'Mondubim'},
#  {'count': 108, 'neighborhood': 'Rodolfo Teófilo'},
#  {'count': 89, 'neighborhood': 'Jardim América'},
#  {'count': 84, 'neighborhood': 'Parque Dois Irmãos'},
#  {'count': 82, 'neighborhood': 'Maraponga'},
#  {'count': 67, 'neighborhood': 'Serrinha'},
#  {'count': 66, 'neighborhood': 'Parquelândia'},
#  {'count': 59, 'neighborhood': 'Aldeota'},
#  {'count': 56, 'neighborhood': 'Alphaville Ceará III'},
#  {'count': 53, 'neighborhood': 'Planalto Ayrton Senna'},
#  {'count': 52, 'neighborhood': 'Meireles'},
#  {'count': 50, 'neighborhood': 'Centro'},
#  {'count': 46, 'neighborhood': 'Dionísio Torres'},
#  {'count': 43, 'neighborhood': 'Fátima'},
#  {'count': 42, 'neighborhood': 'Demócrito Rocha'},
#  {'count': 39, 'neighborhood': 'Bonsucesso'},
#  {'count': 39, 'neighborhood': 'Itaperi'},
#  {'count': 32, 'neighborhood': 'Passaré'},
#  {'count': 31, 'neighborhood': 'Antonio Bezerra'},
#  {'count': 31, 'neighborhood': 'Vila Peri'},
#  {'count': 27, 'neighborhood': 'Granja Portugal'},
#  {'count': 24, 'neighborhood': 'Pici'},
#  {'count': 21, 'neighborhood': 'Itaóca'},
#  {'count': 16, 'neighborhood': 'Varjota'},
#  {'count': 13, 'neighborhood': 'Benfica'},
#  {'count': 12, 'neighborhood': 'P. Potira I'},
#  {'count': 11, 'neighborhood': 'Renascer'},
#  {'count': 10, 'neighborhood': 'Joaquim Távora'},
#  {'count': 9, 'neighborhood': 'Jardim Cearense'},
#  {'count': 9, 'neighborhood': 'Marcos Freire'},
#  {'count': 9, 'neighborhood': 'Parreão'},
#  {'count': 8, 'neighborhood': 'Edson Queiroz'},
#  {'count': 8, 'neighborhood': 'Messejana'},
#  {'count': 7, 'neighborhood': 'Distrito Industrial'},
#  {'count': 6, 'neighborhood': 'Granja Lisboa'},
#  {'count': 6, 'neighborhood': 'Jóquei Clube'},
#  {'count': 6, 'neighborhood': 'Papicu'},
#  {'count': 5, 'neighborhood': 'Cidade dos Funcionários'},
#  {'count': 5, 'neighborhood': 'José Bonifácio'},
#  {'count': 5, 'neighborhood': 'Jurema'},
#  {'count': 5, 'neighborhood': 'Parque São José'},
#  {'count': 4, 'neighborhood': 'Bom Jardim'},
#  {'count': 4, 'neighborhood': 'Jacarecanga'},
#  {'count': 4, 'neighborhood': 'Planalto Caucaia'},
#  {'count': 4, 'neighborhood': 'Quintino Cunha'},
#  {'count': 4, 'neighborhood': 'São Gerardo'},
#  {'count': 4, 'neighborhood': 'São João do Tauape'},
#  {'count': 3, 'neighborhood': 'Amadeu Furtado'},
#  {'count': 3, 'neighborhood': 'Antônio Bezerra'},
#  {'count': 3, 'neighborhood': 'Barra do Ceará'},
#  {'count': 3, 'neighborhood': 'Cambeba'},
#  {'count': 3, 'neighborhood': 'Cararu'},
#  {'count': 3, 'neighborhood': 'Cidade 2000'},
#  {'count': 3, 'neighborhood': 'Cigana'},
#  {'count': 3, 'neighborhood': 'Jangurussu'},
#  {'count': 3, 'neighborhood': 'P. Potira II'},
#  {'count': 3, 'neighborhood': 'Padre Júlio Maria'},
#  {'count': 3, 'neighborhood': 'Pequeno Mondubim'},
#  {'count': 3, 'neighborhood': 'Praia de Iracema'},
#  {'count': 3, 'neighborhood': 'Édson Queiroz'},
#  {'count': 2, 'neighborhood': 'Guararapes'},
#  {'count': 2, 'neighborhood': 'Itambé'},
#  {'count': 2, 'neighborhood': 'Jardim Guanabara'},
#  {'count': 2, 'neighborhood': 'Jardim Iracema'},
#  {'count': 2, 'neighborhood': 'Mata Galinha'},
#  {'count': 2, 'neighborhood': 'P. Potira'},
#  {'count': 2, 'neighborhood': 'Padre Andrade'},
#  {'count': 2, 'neighborhood': 'Parque Araxá'},
#  {'count': 2, 'neighborhood': 'Parque Dois Imrãos'},
#  {'count': 2, 'neighborhood': 'Parque Soledade'},
#  {'count': 2, 'neighborhood': 'Parque dois Irmãos'},
#  {'count': 2, 'neighborhood': 'Patrícia Gomes'},
#  {'count': 2, 'neighborhood': 'Vicente Pinzon'},
#  {'count': 2, 'neighborhood': 'Vila Ellery'},
#  {'count': 1, 'neighborhood': 'ANTONIO BEZERRA'},
#  {'count': 1, 'neighborhood': 'Alvaro Weyne'},
#  {'count': 1, 'neighborhood': 'Antonio Bzerra'},
#  {'count': 1, 'neighborhood': 'Autran Nunes'},
#  {'count': 1, 'neighborhood': 'Açude'},
#  {'count': 1, 'neighborhood': 'Bairro Agua Fria'},
#  {'count': 1, 'neighborhood': 'Bairro de Fátima'},
#  {'count': 1, 'neighborhood': 'Bela Vista'},
#  {'count': 1, 'neighborhood': 'Boa Vista'},
#  {'count': 1, 'neighborhood': 'Cacaru'},
#  {'count': 1, 'neighborhood': 'Cajazeiras'},
#  {'count': 1, 'neighborhood': 'Canindezinho'},
#  {'count': 1, 'neighborhood': 'Castelão'},
#  {'count': 1, 'neighborhood': 'Cidade dos Funcionarios'},
#  {'count': 1, 'neighborhood': 'Coaçu'},
#  {'count': 1, 'neighborhood': 'Condomínio Presidente Castello Branco'},
#  {'count': 1, 'neighborhood': 'Conjunto Nova Metrópole'},
#  {'count': 1, 'neighborhood': 'Conjunto Nova Metrópole V'},
#  {'count': 1, 'neighborhood': 'Cristo Redentor'},
#  {'count': 1, 'neighborhood': 'Cristo Rendentor'},
#  {'count': 1, 'neighborhood': 'Demócrito Rcoha'},
#  {'count': 1, 'neighborhood': 'Dionisio Torres'},
#  {'count': 1, 'neighborhood': 'Distrio Industrial'},
#  {'count': 1, 'neighborhood': 'Farias Brito'},
#  {'count': 1, 'neighborhood': 'Floresta'},
#  {'count': 1, 'neighborhood': 'Fortaleza'},
#  {'count': 1, 'neighborhood': 'Guajiru'},
#  {'count': 1, 'neighborhood': 'Henrique Jorge'},
#  {'count': 1, 'neighborhood': 'JOÃO XXIII'},
#  {'count': 1, 'neighborhood': 'Jereissati I'},
#  {'count': 1, 'neighborhood': 'Jereissati III'},
#  {'count': 1, 'neighborhood': 'José Alencar'},
#  {'count': 1, 'neighborhood': 'Luciano Cavalcante'},
#  {'count': 1, 'neighborhood': 'M'},
#  {'count': 1, 'neighborhood': 'Manuel Sátiro'},
#  {'count': 1, 'neighborhood': 'Monte Castelo'},
#  {'count': 1, 'neighborhood': 'Monteiro'},
#  {'count': 1, 'neighborhood': 'Mucuripe'},
#  {'count': 1, 'neighborhood': 'Nova Metropo'},
#  {'count': 1, 'neighborhood': 'Nova Metropole'},
#  {'count': 1, 'neighborhood': 'Novo Maranguape'},
#  {'count': 1, 'neighborhood': 'PArangaba'},
#  {'count': 1, 'neighborhood': 'PQ. Guadalajara'},
#  {'count': 1, 'neighborhood': 'Panamericano'},
#  {'count': 1, 'neighborhood': 'Parque Genibau'},
#  {'count': 1, 'neighborhood': 'Parque Manibura'},
#  {'count': 1, 'neighborhood': 'Parque Potira'},
#  {'count': 1, 'neighborhood': 'Pefeito José Walter'},
#  {'count': 1, 'neighborhood': 'Perfeito José Walter'},
#  {'count': 1, 'neighborhood': 'Pirambu'},
#  {'count': 1, 'neighborhood': 'Planalto Benjamim'},
#  {'count': 1, 'neighborhood': 'Praia do Futuro'},
#  {'count': 1, 'neighborhood': 'Prefeito Jose Walter'},
#  {'count': 1, 'neighborhood': 'Prefeito José Wlater'},
#  {'count': 1, 'neighborhood': 'Prefeitura José Walter'},
#  {'count': 1, 'neighborhood': 'Presidente Kennedy'},
#  {'count': 1, 'neighborhood': 'Rua O'},
#  {'count': 1, 'neighborhood': 'Salinas'},
#  {'count': 1, 'neighborhood': 'Serinha'},
#  {'count': 1, 'neighborhood': 'Serviluz'},
#  {'count': 1, 'neighborhood': 'São Bento'},
#  {'count': 1, 'neighborhood': 'Vila Cazé'},
#  {'count': 1, 'neighborhood': 'Vila Velha'},
#  {'count': 1, 'neighborhood': 'Vincente Pinzón'},
#  {'count': 1, 'neighborhood': 'centro'},
#  {'count': 1, 'neighborhood': 'itaperi'},
#  {'count': 1, 'neighborhood': 'serrinha'},
#  {'count': 1, 'neighborhood': 'vila União'}]

# %%
# number of religion nodes identified in the database
    
sql_query("""
    SELECT COUNT(*) as religion_count
    FROM nodes_tags
    WHERE key = 'religion'
""")
# Out:
# [{'religion_count': 38}]

# %%
sql_query("""
    SELECT key
    FROM ways_tags
    GROUP BY key
    ORDER BY key
""")
# Out:
# [{'key': '2'},
#  {'key': '2014worldcup'},
#  {'key': 'AConst'},
#  {'key': 'AProjetada'},
#  {'key': 'Densidade'},
#  {'key': 'FID'},
#  {'key': 'FIXME'},
#  {'key': 'Gabarito'},
#  {'key': 'L1'},
#  {'key': 'L2'},
#  {'key': 'L3'},
#  {'key': 'L4'},
#  {'key': 'Profundidade'},
#  {'key': 'Rotulo'},
#  {'key': 'Testada'},
#  {'key': 'access'},
#  {'key': 'admin_level'},
#  {'key': 'advertising'},
#  {'key': 'aeroway'},
#  {'key': 'alt_name'},
#  {'key': 'amenity'},
#  {'key': 'amenity_1'},
#  {'key': 'anchorage:category'},
#  {'key': 'angle'},
#  {'key': 'area'},
#  {'key': 'atm'},
#  {'key': 'backward'},
#  {'key': 'barrier'},
#  {'key': 'bench'},
#  {'key': 'bicycle'},
#  {'key': 'bin'},
#  {'key': 'boat'},
#  {'key': 'border_type'},
#  {'key': 'boundary'},
#  {'key': 'brand'},
#  {'key': 'bridge'},
#  {'key': 'building'},
#  {'key': 'building_1'},
#  {'key': 'bus'},
#  {'key': 'cable_submarine:category'},
#  {'key': 'cable_submarine:name'},
#  {'key': 'cables'},
#  {'key': 'canoe'},
#  {'key': 'capacity'},
#  {'key': 'city'},
#  {'key': 'clothes'},
#  {'key': 'colour'},
#  {'key': 'construction'},
#  {'key': 'content'},
#  {'key': 'converted_by'},
#  {'key': 'country'},
#  {'key': 'covered'},
#  {'key': 'craft'},
#  {'key': 'created_by'},
#  {'key': 'crop'},
#  {'key': 'crossing'},
#  {'key': 'crossing_ref'},
#  {'key': 'cuisine'},
#  {'key': 'cutting'},
#  {'key': 'cycleway'},
#  {'key': 'delivery'},
#  {'key': 'denomination'},
#  {'key': 'densidade'},
#  {'key': 'department'},
#  {'key': 'description'},
#  {'key': 'description:pt'},
#  {'key': 'destination'},
#  {'key': 'diesel'},
#  {'key': 'disabled'},
#  {'key': 'dispensing'},
#  {'key': 'drive_through'},
#  {'key': 'ele'},
#  {'key': 'electrified'},
#  {'key': 'elevation'},
#  {'key': 'elevator'},
#  {'key': 'email'},
#  {'key': 'embankment'},
#  {'key': 'emergency'},
#  {'key': 'en'},
#  {'key': 'fax'},
#  {'key': 'fee'},
#  {'key': 'fence_type'},
#  {'key': 'fixme'},
#  {'key': 'foot'},
#  {'key': 'footway'},
#  {'key': 'for'},
#  {'key': 'ford'},
#  {'key': 'forward'},
#  {'key': 'frequency'},
#  {'key': 'gauge'},
#  {'key': 'golf'},
#  {'key': 'handrail'},
#  {'key': 'height'},
#  {'key': 'highway'},
#  {'key': 'historic'},
#  {'key': 'hoops'},
#  {'key': 'horse'},
#  {'key': 'hour_on'},
#  {'key': 'housename'},
#  {'key': 'housenumber'},
#  {'key': 'housing_units'},
#  {'key': 'iata'},
#  {'key': 'icao'},
#  {'key': 'incline'},
#  {'key': 'int_name'},
#  {'key': 'intermittent'},
#  {'key': 'internet_access'},
#  {'key': 'junction'},
#  {'key': 'landuse'},
#  {'key': 'lane'},
#  {'key': 'lanes'},
#  {'key': 'layer'},
#  {'key': 'leaf_cycle'},
#  {'key': 'leaf_type'},
#  {'key': 'left'},
#  {'key': 'leisure'},
#  {'key': 'length'},
#  {'key': 'level'},
#  {'key': 'levels'},
#  {'key': 'lit'},
#  {'key': 'loc_name'},
#  {'key': 'location'},
#  {'key': 'man_made'},
#  {'key': 'material'},
#  {'key': 'maxspeed'},
#  {'key': 'maxstay'},
#  {'key': 'military'},
#  {'key': 'min_height'},
#  {'key': 'motor_vehicle'},
#  {'key': 'motorboat'},
#  {'key': 'motorcycle'},
#  {'key': 'name'},
#  {'key': 'name2'},
#  {'key': 'natural'},
#  {'key': 'network'},
#  {'key': 'noname'},
#  {'key': 'note'},
#  {'key': 'office'},
#  {'key': 'old_name'},
#  {'key': 'oneway'},
#  {'key': 'opening_hours'},
#  {'key': 'operator'},
#  {'key': 'operator_1'},
#  {'key': 'orientation'},
#  {'key': 'outdoor_seating'},
#  {'key': 'park_ride'},
#  {'key': 'parking'},
#  {'key': 'part'},
#  {'key': 'parts'},
#  {'key': 'phone'},
#  {'key': 'pipeline_submarine:category'},
#  {'key': 'pipeline_submarine:product'},
#  {'key': 'place'},
#  {'key': 'platforms'},
#  {'key': 'podcast'},
#  {'key': 'population'},
#  {'key': 'postal_code'},
#  {'key': 'postcode'},
#  {'key': 'power'},
#  {'key': 'practical'},
#  {'key': 'preferred_direction'},
#  {'key': 'produce'},
#  {'key': 'psv'},
#  {'key': 'pt'},
#  {'key': 'public_transport'},
#  {'key': 'rail'},
#  {'key': 'railway'},
#  {'key': 'ramp'},
#  {'key': 'recuofrente'},
#  {'key': 'recuofundo'},
#  {'key': 'recuolateral'},
#  {'key': 'ref'},
#  {'key': 'religion'},
#  {'key': 'rental'},
#  {'key': 'repair'},
#  {'key': 'right'},
#  {'key': 'rooms'},
#  {'key': 'sale'},
#  {'key': 'seasonal'},
#  {'key': 'second_hand'},
#  {'key': 'segregated'},
#  {'key': 'service'},
#  {'key': 'shape'},
#  {'key': 'shelter'},
#  {'key': 'shop'},
#  {'key': 'short_name'},
#  {'key': 'sidewalk'},
#  {'key': 'smoking'},
#  {'key': 'smoothness'},
#  {'key': 'social_facility'},
#  {'key': 'source'},
#  {'key': 'sport'},
#  {'key': 'stars'},
#  {'key': 'state'},
#  {'key': 'street'},
#  {'key': 'studio'},
#  {'key': 'subur'},
#  {'key': 'subway'},
#  {'key': 'supervised'},
#  {'key': 'surface'},
#  {'key': 'tactile_paving'},
#  {'key': 'takeaway'},
#  {'key': 'tank:category'},
#  {'key': 'tidal'},
#  {'key': 'tipo'},
#  {'key': 'tourism'},
#  {'key': 'tracks'},
#  {'key': 'train'},
#  {'key': 'tunnel'},
#  {'key': 'type'},
#  {'key': 'uniPav'},
#  {'key': 'usage'},
#  {'key': 'voltage'},
#  {'key': 'wall'},
#  {'key': 'water'},
#  {'key': 'waterway'},
#  {'key': 'website'},
#  {'key': 'wetland'},
#  {'key': 'wheelchair'},
#  {'key': 'width'},
#  {'key': 'wikidata'},
#  {'key': 'wikipedia'},
#  {'key': 'wires'},
#  {'key': 'wood'}]

# %%
sql_query("""
    SELECT *
    FROM ways_tags
    WHERE id = 183988544
""")
# Out:
# [{'id': 183988544,
#   'key': 'name',
#   'type': 'regular',
#   'value': 'Casa José de Alencar (CJA)'},
#  {'id': 183988544,
#   'key': 'opening_hours',
#   'type': 'regular',
#   'value': 'Mo-Su 08:00-18:00'},
#  {'id': 183988544, 'key': 'tourism', 'type': 'regular', 'value': 'attraction'}]

# %%
sql_query("""
    SELECT *
    FROM ways_tags
    WHERE key = 'tourism'
""")
# Out:
# [{'id': 24419367, 'key': 'tourism', 'type': 'regular', 'value': 'viewpoint'},
#   'lon': -38.6172759,
#   'timestamp': '2012-02-28T12:53:29Z',
#   'uid': 145275,
#   'user': 'Paper_',
#   'version': 2},
#  {'changeset': 23204765,
#   'id': 100429507,
#   'lat': -3.7173614,
#   'lon': -38.5223213,
#   'timestamp': '2014-06-27T02:56:38Z',
#   'uid': 612405,
#   'user': 'Narcélio de Sá',
#   'version': 8},
#  {'changeset': 569903,
#   'id': 100430485,
#   'lat': -3.8231491,
#   'lon': -38.4017816,
#   'timestamp': '2008-12-22T23:01:40Z',
#   'uid': 1596,
#   'user': 'Claudomiro',
#   'version': 5}]

# %%
sql_query("""
    SELECT COUNT(*)
    FROM ways_tags

# %% [markdown]
# ## Idea for Exploration: Identify Neighborhood Saturation Level
# Identify how many distinct streets are in each neighborhood, then how many nodes and ways have been tagged in each neighborhood per street, and take that ratio as the saturation level for each neighborhood. This can be a flag for potential users to which neighborhoods need the most work, so they can focus their efforts here.

# %%
sql_query("SELECT * FROM nodes WHERE id = 479234596")
# Out:
# [{'changeset': 13933916,
#   'id': 479234596,
#   'lat': -3.7229979,
#   'lon': -38.5507686,
#   'timestamp': '2012-11-19T16:29:38Z',
#   'uid': 99364,
#   'user': 'Arthur Rodrigues',
#   'version': 2}]

# %%
sql_query("""
    SELECT GROUP_CONCAT(DISTINCT(id)) AS ids, COUNT(*) AS count, value AS neighborhood
    FROM (SELECT * FROM nodes_tags WHERE key = 'subur' UNION ALL SELECT * FROM ways_tags WHERE key = 'subur')
    GROUP BY neighborhood
    ORDER BY count DESC
""")
# Out:
# [{'count': 719,
#   'ids': '358701550,373769832,373769871,373769909,373769935,373769936,373769943,373790989,379687401,379687402,380017813,380017815,380017816,380017817,380017821,380017822,380017825,380017826,380017827,380017828,380017829,380017830,380017832,380017833,380017834,380017836,380017838,380017839,380017840,380017841,380017843,380017844,380017845,380017846,380017847,380017848,385746444,386889822,386889823,386889824,386889825,386889826,386889827,386889828,386889829,386889831,386889832,386889833,386889834,386889835,386889836,386889837,386889838,386889839,386889840,386889841,386889842,386889843,388091188,388168411,388168412,388168414,388168415,388168416,388168417,388168418,388168419,388168420,388168421,388168422,388168423,388168424,388168425,388168426,388168427,388168428,388168429,388168431,388168432,388168433,388168434,388168435,388168436,388168437,388168438,393078959,393078960,393078961,393078962,393078963,393078964,393078965,393078966,393078967,393078968,393078969,393078970,393078971,393078972,393078973,393078974,393078975,393078976,393078977,393078978,393078979,393078980,393078981,393078982,393078983,393078984,393078985,393078986,393078987,393078988,393078989,393078990,393078992,393078993,393078994,393078995,393078996,393078997,393078999,393079000,393079001,393079002,393079003,393079004,393079006,393079007,393079008,393079009,393079010,393079011,393079012,393079013,393079014,393079015,393079016,393079017,393079020,393079021,393079022,393079023,393079024,393079025,393079027,393079028,393079029,393079030,393079033,393079955,395118145,395118146,395118147,395118148,457721722,457721723,457721725,457721726,457721727,457721729,457721730,475666654,475666656,475666657,475666659,475666660,475666661,475666663,475666665,475666666,475666669,475666670,475666673,475666675,475666
#  {'count': 5,
#   'ids': '4476809862,4477147672,4477171028,185832800,243311748',
#   'neighborhood': 'José Bonifácio'},
#  {'count': 5,
#   'ids': '4446968554,4446968555,383356485,447610106,447610717',
#   'neighborhood': 'Jurema'},
#  {'count': 5,
#   'ids': '4478193794,4478193795,4478193796,4478193797,4478193798',
#   'neighborhood': 'Parque São José'},
#  {'count': 4,
#   'ids': '4003097608,4202755959,357291230,420340211',
#   'neighborhood': 'Bom Jardim'},
#  {'count': 4,
#   'ids': '428122441,428122442,428122446,428122447',
#   'neighborhood': 'Jacarecanga'},
#  {'count': 4,
#   'ids': '4183752962,4340612296,417988588,482031804',
#   'neighborhood': 'Planalto Caucaia'},
#  {'count': 4,
#   'ids': '331232906,365020875,436932352,436933361',
#   'neighborhood': 'Quintino Cunha'},
#  {'count': 4,
#   'ids': '39915294,376750068,403882447,478185746',
#   'neighborhood': 'São Gerardo'},
#  {'count': 4,
#   'ids': '1733886742,4243040829,316477046,440212693',
#   'neighborhood': 'São João do Tauape'},
#  {'count': 3,
#   'ids': '477364089,4263231431,4455909657',
#   'neighborhood': 'Amadeu Furtado'},
#  {'count': 3,
#   'ids': '4228800830,4476891450,352873058',
#   'neighborhood': 'Antônio Bezerra'},
#  {'count': 3,
#   'ids': '4052064311,4476900785,4629321260',
#   'neighborhood': 'Barra do Ceará'},
#  {'count': 3,
#   'ids': '3013022937,349220651,415118930',
#   'neighborhood': 'Cambeba'},
#  {'count': 3, 'ids': '432560107,432657640,432779444', 'neighborhood': 'Cararu'},
#  {'count': 3,
#   'ids': '4262975299,397386392,397386826',
#   'neighborhood': 'Cidade 2000'},
#  {'count': 3, 'ids': '483591377,483591381,483591385', 'neighborhood': 'Cigana'},
#  {'count': 3,
#   'ids': '4464798968,4464798969,449528632',
#   'neighborhood': 'Jangurussu'},
#  {'count': 3,
#   'ids': '447601750,447601752,447607633',
#   'neighborhood': 'P. Potira II'},
#  {'count': 3,
#   'ids': '483591370,483591371,483591373',
#   'neighborhood': 'Padre Júlio Maria'},
#  {'count': 3,
#   'ids': '158226275,158226395,158226539',
#   'neighborhood': 'Pequeno Mondubim'},
#  {'count': 3,
#   'ids': '243217562,243224678,377673501',
#   'neighborhood': 'Praia de Iracema'},
#  {'count': 3,
#   'ids': '3542542421,3818829538,378471616',
#   'neighborhood': 'Édson Queiroz'},
#  {'count': 2, 'ids': '4365020766,423453810', 'neighborhood': 'Guararapes'},
#  {'count': 2, 'ids': '416593871,477410547', 'neighborhood': 'Itambé'},
#  {'count': 2, 'ids': '358218517,420341446', 'neighborhood': 'Jardim Guanabara'},
#  {'count': 2, 'ids': '4176805850,4176813531', 'neighborhood': 'Jardim Iracema'},
#  {'count': 2, 'ids': '4470101589,4470101590', 'neighborhood': 'Mata Galinha'},
#  {'count': 2, 'ids': '4444987424,447601491', 'neighborhood': 'P. Potira'},
#  {'count': 2, 'ids': '4228830551,352867963', 'neighborhood': 'Padre Andrade'},
#  {'count': 2, 'ids': '4495656567,4495699133', 'neighborhood': 'Parque Araxá'},
#  {'count': 2,
#   'ids': '2052016682,4464251089',
#   'neighborhood': 'Parque Dois Imrãos'},
#  {'count': 2, 'ids': '477407306,477409289', 'neighborhood': 'Parque Soledade'},
#  {'count': 2,
#   'ids': '2052022506,4476004535',
#   'neighborhood': 'Parque dois Irmãos'},
#  {'count': 2, 'ids': '420338921,420339875', 'neighborhood': 'Patrícia Gomes'},
#  {'count': 2, 'ids': '1622201461,4163363902', 'neighborhood': 'Vicente Pinzon'},
#  {'count': 2, 'ids': '4228843489,478187116', 'neighborhood': 'Vila Ellery'},
#  {'count': 1, 'ids': '424778821', 'neighborhood': 'ANTONIO BEZERRA'},
#  {'count': 1, 'ids': '304313086', 'neighborhood': 'Alvaro Weyne'},
#  {'count': 1, 'ids': '392180213', 'neighborhood': 'Antonio Bzerra'},
#  {'count': 1, 'ids': '329552695', 'neighborhood': 'Autran Nunes'},
#  {'count': 1, 'ids': '477409515', 'neighborhood': 'Açude'},
#  {'count': 1, 'ids': '296913800', 'neighborhood': 'Bairro Agua Fria'},
#  {'count': 1, 'ids': '431536383', 'neighborhood': 'Bairro de Fátima'},
#  {'count': 1, 'ids': '4496129032', 'neighborhood': 'Bela Vista'},
#  {'count': 1, 'ids': '1704730112', 'neighborhood': 'Boa Vista'},
#  {'count': 1, 'ids': '432884686', 'neighborhood': 'Cacaru'},
#  {'count': 1, 'ids': '440214433', 'neighborhood': 'Cajazeiras'},
#  {'count': 1, 'ids': '4478202742', 'neighborhood': 'Canindezinho'},
#  {'count': 1, 'ids': '4396343172', 'neighborhood': 'Castelão'},
#  {'count': 1, 'ids': '445466414', 'neighborhood': 'Cidade dos Funcionarios'},
#  {'count': 1, 'ids': '4478210808', 'neighborhood': 'Coaçu'},
#  {'count': 1,
#   'ids': '4482462527',
#   'neighborhood': 'Condomínio Presidente Castello Branco'},
#  {'count': 1, 'ids': '4419279529', 'neighborhood': 'Conjunto Nova Metrópole'},
#  {'count': 1, 'ids': '4419267910', 'neighborhood': 'Conjunto Nova Metrópole V'},
#  {'count': 1, 'ids': '4478206861', 'neighborhood': 'Cristo Redentor'},
#  {'count': 1, 'ids': '4477033016', 'neighborhood': 'Cristo Rendentor'},
#  {'count': 1, 'ids': '4494489642', 'neighborhood': 'Demócrito Rcoha'},
#  {'count': 1, 'ids': '4063545207', 'neighborhood': 'Dionisio Torres'},
#  {'count': 1, 'ids': '369239403', 'neighborhood': 'Distrio Industrial'},
#  {'count': 1, 'ids': '4359225081', 'neighborhood': 'Farias Brito'},
#  {'count': 1, 'ids': '193187815', 'neighborhood': 'Floresta'},
#  {'count': 1, 'ids': '4469548745', 'neighborhood': 'Fortaleza'},
#  {'count': 1, 'ids': '4476881588', 'neighborhood': 'Guajiru'},
#  {'count': 1, 'ids': '4263192253', 'neighborhood': 'Henrique Jorge'},
#  {'count': 1, 'ids': '3469922228', 'neighborhood': 'JOÃO XXIII'},
#  {'count': 1, 'ids': '1194256050', 'neighborhood': 'Jereissati I'},
#  {'count': 1, 'ids': '396800422', 'neighborhood': 'Jereissati III'},
#  {'count': 1, 'ids': '479608897', 'neighborhood': 'José Alencar'},
#  {'count': 1, 'ids': '438474855', 'neighborhood': 'Luciano Cavalcante'},
#  {'count': 1, 'ids': '4469012491', 'neighborhood': 'M'},
#  {'count': 1, 'ids': '366310650', 'neighborhood': 'Manuel Sátiro'},
#  {'count': 1, 'ids': '403884744', 'neighborhood': 'Monte Castelo'},
#  {'count': 1, 'ids': '4492719395', 'neighborhood': 'Monteiro'},
#  {'count': 1, 'ids': '4224571254', 'neighborhood': 'Mucuripe'},
#  {'count': 1, 'ids': '416631406', 'neighborhood': 'Nova Metropo'},
#  {'count': 1, 'ids': '390753969', 'neighborhood': 'Nova Metropole'},
#  {'count': 1, 'ids': '374034311', 'neighborhood': 'Novo Maranguape'},
#  {'count': 1, 'ids': '4471947560', 'neighborhood': 'PArangaba'},
#  {'count': 1, 'ids': '348444672', 'neighborhood': 'PQ. Guadalajara'},
#  {'count': 1, 'ids': '4263222550', 'neighborhood': 'Panamericano'},
#  {'count': 1, 'ids': '472353359', 'neighborhood': 'Parque Genibau'},
#  {'count': 1, 'ids': '3011756533', 'neighborhood': 'Parque Manibura'},
#  {'count': 1, 'ids': '385177294', 'neighborhood': 'Parque Potira'},
#  {'count': 1, 'ids': '4466275273', 'neighborhood': 'Pefeito José Walter'},
#  {'count': 1, 'ids': '4466527288', 'neighborhood': 'Perfeito José Walter'},
#  {'count': 1, 'ids': '3075425630', 'neighborhood': 'Pirambu'},
#  {'count': 1, 'ids': '475930260', 'neighborhood': 'Planalto Benjamim'},
#  {'count': 1, 'ids': '4478189359', 'neighborhood': 'Praia do Futuro'},
#  {'count': 1, 'ids': '4466658149', 'neighborhood': 'Prefeito Jose Walter'},
#  {'count': 1, 'ids': '4466698123', 'neighborhood': 'Prefeito José Wlater'},
#  {'count': 1, 'ids': '4466392512', 'neighborhood': 'Prefeitura José Walter'},
#  {'count': 1, 'ids': '357288252', 'neighborhood': 'Presidente Kennedy'},
#  {'count': 1, 'ids': '484544062', 'neighborhood': 'Rua O'},
#  {'count': 1, 'ids': '416176581', 'neighborhood': 'Salinas'},
#  {'count': 1, 'ids': '4476004516', 'neighborhood': 'Serinha'},
#  {'count': 1, 'ids': '3096130051', 'neighborhood': 'Serviluz'},
#  {'count': 1, 'ids': '4352718240', 'neighborhood': 'São Bento'},
#  {'count': 1, 'ids': '482037800', 'neighborhood': 'Vila Cazé'},
#  {'count': 1, 'ids': '4450073422', 'neighborhood': 'Vila Velha'},
#  {'count': 1, 'ids': '417050909', 'neighborhood': 'Vincente Pinzón'},
#  {'count': 1, 'ids': '396394696', 'neighborhood': 'centro'},
#  {'count': 1, 'ids': '4475941070', 'neighborhood': 'itaperi'},
#  {'count': 1, 'ids': '380294074', 'neighborhood': 'serrinha'},
#  {'count': 1, 'ids': '4483047625', 'neighborhood': 'vila União'}]

# %%
sql_query("""
    SELECT
        COUNT(DISTINCT(table1.value)) AS streets_count,
        table2.value AS neighborhood,
        COUNT(*) AS tags_count,
        ROUND( (COUNT(*) * 1.0) / (COUNT(DISTINCT(table1.value)) * 1.0), 2) AS saturation_ratio
    FROM
        (SELECT * FROM nodes_tags UNION SELECT * FROM ways_tags) table1,
        (SELECT * FROM nodes_tags UNION SELECT * FROM ways_tags) table2
    WHERE
        table1.id = table2.id
        AND table1.key = 'street'
        AND table2.key = 'subur'
    GROUP BY neighborhood
    HAVING streets_count >= 5
    ORDER BY saturation_ratio
    LIMIT 5
""")
# Out:
# [{'neighborhood': 'Granja Lisboa',
#   'saturation_ratio': 1.0,
#   'streets_count': 6,
#   'tags_count': 6},
#  {'neighborhood': 'Marcos Freire',
#   'saturation_ratio': 1.0,
#   'streets_count': 9,
#   'tags_count': 9},
#  {'neighborhood': 'Renascer',
#   'saturation_ratio': 1.0,
#   'streets_count': 11,
#   'tags_count': 11},
#  {'neighborhood': 'Benfica',
#   'saturation_ratio': 1.18,
#   'streets_count': 11,
#   'tags_count': 13},
#  {'neighborhood': 'Messejana',
#   'saturation_ratio': 1.33,
#   'streets_count': 6,
#   'tags_count': 8}]

# %%
sql_query("SELECT key FROM nodes_tags GROUP BY key")
# Out:
# [{'key': 'Exercicios'},
#  {'key': 'GEOCODIGO'},
#  {'key': 'access'},
#  {'key': 'aeroway'},
#  {'key': 'alt_name'},
#  {'key': 'amenity'},
#  {'key': 'amenity_1'},
#  {'key': 'ar'},
#  {'key': 'artwork_type'},
#  {'key': 'atm'},
#  {'key': 'attraction'},
#  {'key': 'backrest'},
#  {'key': 'barrier'},
#  {'key': 'be'},
#  {'key': 'beacon_isolated_danger:colour'},
#  {'key': 'beacon_isolated_danger:colour_pattern'},
#  {'key': 'beauty'},
#  {'key': 'bench'},
#  {'key': 'bg'},
#  {'key': 'bicycle'},
#  {'key': 'bicycle:chain_tool'},
#  {'key': 'bicycle:pump'},
#  {'key': 'bicycle_parking'},
#  {'key': 'bitcoin'},
#  {'key': 'bn'},
#  {'key': 'br'},
#  {'key': 'braille:lg'},
#  {'key': 'brand'},
#  {'key': 'building'},
#  {'key': 'buoy_isolated_danger:colour'},
#  {'key': 'buoy_isolated_danger:colour_pattern'},
#  {'key': 'buoy_isolated_danger:shape'},
#  {'key': 'buoy_lateral:category'},
#  {'key': 'buoy_lateral:colour'},
#  {'key': 'buoy_lateral:shape'},
#  {'key': 'buoy_lateral:system'},
#  {'key': 'bus'},
#  {'key': 'capacity'},
#  {'key': 'ce'},
#  {'key': 'city'},
#  {'key': 'colour'},
#  {'key': 'content'},
#  {'key': 'continent'},
#  {'key': 'country'},
#  {'key': 'country_code'},
#  {'key': 'covered'},
#  {'key': 'craft'},
#  {'key': 'created_by'},
#  {'key': 'crossing'},
#  {'key': 'crossing_ref'},
#  {'key': 'cuisine'},
#  {'key': 'dangerous'},
#  {'key': 'de'},
#  {'key': 'delivery'},
#  {'key': 'denomination'},
#  {'key': 'denotation'},
#  {'key': 'description'},
#  {'key': 'direction'},
#  {'key': 'drive_through'},
#  {'key': 'el'},
#  {'key': 'ele'},
#  {'key': 'email'},
#  {'key': 'emergency'},
#  {'key': 'en'},
#  {'key': 'entrance'},
#  {'key': 'eo'},
#  {'key': 'es'},
#  {'key': 'fa'},
#  {'key': 'fee'},
#  {'key': 'fixme'},
#  {'key': 'flag'},
#  {'key': 'floor'},
#  {'key': 'foot'},
#  {'key': 'harbour'},
#  {'key': 'harbour:category'},
#  {'key': 'he'},
#  {'key': 'height'},
#  {'key': 'highway'},
#  {'key': 'historic'},
#  {'key': 'horse'},
#  {'key': 'housename'},
#  {'key': 'housenumber'},
#  {'key': 'hy'},
#  {'key': 'icao'},
#  {'key': 'internet_access'},
#  {'key': 'is_in'},
#  {'key': 'ja'},
#  {'key': 'ka'},
#  {'key': 'kk'},
#  {'key': 'ko'},
#  {'key': 'la'},
#  {'key': 'lamp_type'},
#  {'key': 'landmark:category'},
#  {'key': 'landmark:function'},
#  {'key': 'landuse'},
#  {'key': 'leaf_cycle'},
#  {'key': 'leaf_type'},
#  {'key': 'leisure'},
#  {'key': 'level'},
#  {'key': 'levels'},
#  {'key': 'light:category'},
#  {'key': 'light:character'},
#  {'key': 'light:colour'},
#  {'key': 'light:group'},
#  {'key': 'light:height'},
#  {'key': 'light:period'},
#  {'key': 'light:range'},
#  {'key': 'light:reference'},
#  {'key': 'light_rail'},
#  {'key': 'loc_name'},
#  {'key': 'local_ref'},
#  {'key': 'lt'},
#  {'key': 'lv'},
#  {'key': 'man_made'},
#  {'key': 'material'},
#  {'key': 'maxstay'},
#  {'key': 'method'},
#  {'key': 'microbrewery'},
#  {'key': 'military'},
#  {'key': 'mk'},
#  {'key': 'mn'},
#  {'key': 'mooring:category'},
#  {'key': 'motor_vehicle'},
#  {'key': 'motorcar'},
#  {'key': 'motorcycle'},
#  {'key': 'mr'},
#  {'key': 'name'},
#  {'key': 'natural'},
#  {'key': 'network'},
#  {'key': 'noexit'},
#  {'key': 'note'},
#  {'key': 'office'},
#  {'key': 'opening_hours'},
#  {'key': 'operator'},
#  {'key': 'os'},
#  {'key': 'outdoor_seating'},
#  {'key': 'parking'},
#  {'key': 'phone'},
#  {'key': 'pilotage'},
#  {'key': 'pl'},
#  {'key': 'place'},
#  {'key': 'population'},
#  {'key': 'postcode'},
#  {'key': 'power'},
#  {'key': 'pt'},
#  {'key': 'public_transport'},
#  {'key': 'raceway'},
#  {'key': 'radio_station:category'},
#  {'key': 'rail'},
#  {'key': 'railway'},
#  {'key': 'ref'},
#  {'key': 'religion'},
#  {'key': 'restricted_area:category'},
#  {'key': 'rock:water_level'},
#  {'key': 'ru'},
#  {'key': 'shape'},
#  {'key': 'shelter'},
#  {'key': 'shop'},
#  {'key': 'short_name'},
#  {'key': 'smoking'},
#  {'key': 'source'},
#  {'key': 'speciality'},
#  {'key': 'sport'},
#  {'key': 'sr'},
#  {'key': 'state'},
#  {'key': 'state_capital'},
#  {'key': 'street'},
#  {'key': 'subur'},
#  {'key': 'subway'},
#  {'key': 'takeaway'},
#  {'key': 'tank:category'},
#  {'key': 'telephone_cards'},
#  {'key': 'tg'},
#  {'key': 'th'},
#  {'key': 'topmark:colour'},
#  {'key': 'topmark:shape'},
#  {'key': 'tourism'},
#  {'key': 'traffic_calming'},
#  {'key': 'traffic_signals'},
#  {'key': 'train'},
#  {'key': 'type'},
#  {'key': 'uk'},
#  {'key': 'website'},
#  {'key': 'wheelchair'},
#  {'key': 'width'},
#  {'key': 'wifi'},
#  {'key': 'wikidata'},
#  {'key': 'wikipedia'},
#  {'key': 'wreck:category'},
#  {'key': 'zh'}]

# %%
sql_query("""
    SELECT *, (SELECT GROUP_CONCAT(DISTINCT(id)) FROM (SELECT * FROM nodes_tags WHERE key = 'subur' UNION ALL SELECT * FROM ways_tags WHERE key = 'subur')
    FROM nodes,
    (
        SELECT GROUP_CONCAT(DISTINCT(id)) AS ids, COUNT(*) AS count, value AS neighborhood
        FROM (SELECT * FROM nodes_tags WHERE key = 'subur' UNION ALL SELECT * FROM ways_tags WHERE key = 'subur')
        GROUP BY neighborhood
    ) subquery1
    WHERE nodes.id IN subquery1.ids

""")
# Out:
# ERROR:root:An unexpected error occurred while tokenizing input
# The following traceback may be corrupted or invalid
# The error message is: ('EOF in multi-line string', (1, 0))
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-35-df2c68abd1fd> in <module>()
#       9     WHERE nodes.id IN sub.ids
#      10
# ---> 11 """)
#
# <ipython-input-6-0516c5493890> in sql_query(syntax, output)
#       2 # runs query, then outputs each record as a dict object, by default
#       3 def sql_query(syntax, output=True):
# ----> 4     cur.execute(syntax)
#       5     if output == True:
#       6         pprint.pprint([dict(i) for i in cur.fetchall()])
#
# OperationalError: no such table: sub.ids

# %%
# number of tags per neighborhood
sql_query("""
    SELECT COUNT(*) as count, value as neighborhood
    FROM (SELECT * FROM nodes_tags WHERE key = 'subur' UNION ALL SELECT * FROM ways_tags WHERE key = 'subur')
    GROUP BY neighborhood
    ORDER BY count DESC
""")
# Out:
# [{'count': 719, 'neighborhood': 'Parque Albano'},
#  {'count': 451, 'neighborhood': 'Montese'},
#  {'count': 218, 'neighborhood': 'Prefeito José Walter'},
#  {'count': 171, 'neighborhood': 'Damas'},
#  {'count': 169, 'neighborhood': 'Conjunto Ceará'},
#  {'count': 149, 'neighborhood': 'Parangaba'},
#  {'count': 134, 'neighborhood': 'Vila União'},
#  {'count': 128, 'neighborhood': 'Mondubim'},
#  {'count': 108, 'neighborhood': 'Rodolfo Teófilo'},
#  {'count': 89, 'neighborhood': 'Jardim América'},
#  {'count': 84, 'neighborhood': 'Parque Dois Irmãos'},
#  {'count': 82, 'neighborhood': 'Maraponga'},
#  {'count': 67, 'neighborhood': 'Serrinha'},
#  {'count': 66, 'neighborhood': 'Parquelândia'},
#  {'count': 59, 'neighborhood': 'Aldeota'},
#  {'count': 56, 'neighborhood': 'Alphaville Ceará III'},
#  {'count': 53, 'neighborhood': 'Planalto Ayrton Senna'},
#  {'count': 52, 'neighborhood': 'Meireles'},
#  {'count': 50, 'neighborhood': 'Centro'},
#  {'count': 46, 'neighborhood': 'Dionísio Torres'},
#  {'count': 43, 'neighborhood': 'Fátima'},
#  {'count': 42, 'neighborhood': 'Demócrito Rocha'},
#  {'count': 39, 'neighborhood': 'Bonsucesso'},
#  {'count': 39, 'neighborhood': 'Itaperi'},
#  {'count': 32, 'neighborhood': 'Passaré'},
#  {'count': 31, 'neighborhood': 'Antonio Bezerra'},
#  {'count': 31, 'neighborhood': 'Vila Peri'},
#  {'count': 27, 'neighborhood': 'Granja Portugal'},
#  {'count': 24, 'neighborhood': 'Pici'},
#  {'count': 21, 'neighborhood': 'Itaóca'},
#  {'count': 16, 'neighborhood': 'Varjota'},
#  {'count': 13, 'neighborhood': 'Benfica'},
#  {'count': 12, 'neighborhood': 'P. Potira I'},
#  {'count': 11, 'neighborhood': 'Renascer'},
#  {'count': 10, 'neighborhood': 'Joaquim Távora'},
#  {'count': 9, 'neighborhood': 'Jardim Cearense'},
#  {'count': 9, 'neighborhood': 'Marcos Freire'},
#  {'count': 9, 'neighborhood': 'Parreão'},
#  {'count': 8, 'neighborhood': 'Edson Queiroz'},
#  {'count': 8, 'neighborhood': 'Messejana'},
#  {'count': 7, 'neighborhood': 'Distrito Industrial'},
#  {'count': 6, 'neighborhood': 'Granja Lisboa'},
#  {'count': 6, 'neighborhood': 'Jóquei Clube'},
#  {'count': 6, 'neighborhood': 'Papicu'},
#  {'count': 5, 'neighborhood': 'Cidade dos Funcionários'},
#  {'count': 5, 'neighborhood': 'José Bonifácio'},
#  {'count': 5, 'neighborhood': 'Jurema'},
#  {'count': 5, 'neighborhood': 'Parque São José'},
#  {'count': 4, 'neighborhood': 'Bom Jardim'},
#  {'count': 4, 'neighborhood': 'Jacarecanga'},
#  {'count': 4, 'neighborhood': 'Planalto Caucaia'},
#  {'count': 4, 'neighborhood': 'Quintino Cunha'},
#  {'count': 4, 'neighborhood': 'São Gerardo'},
#  {'count': 4, 'neighborhood': 'São João do Tauape'},
#  {'count': 3, 'neighborhood': 'Amadeu Furtado'},
#  {'count': 3, 'neighborhood': 'Antônio Bezerra'},
#  {'count': 3, 'neighborhood': 'Barra do Ceará'},
#  {'count': 3, 'neighborhood': 'Cambeba'},
#  {'count': 3, 'neighborhood': 'Cararu'},
#  {'count': 3, 'neighborhood': 'Cidade 2000'},
#  {'count': 3, 'neighborhood': 'Cigana'},
#  {'count': 3, 'neighborhood': 'Jangurussu'},
#  {'count': 3, 'neighborhood': 'P. Potira II'},
#  {'count': 3, 'neighborhood': 'Padre Júlio Maria'},
#  {'count': 3, 'neighborhood': 'Pequeno Mondubim'},
#  {'count': 3, 'neighborhood': 'Praia de Iracema'},
#  {'count': 3, 'neighborhood': 'Édson Queiroz'},
#  {'count': 2, 'neighborhood': 'Guararapes'},
#  {'count': 2, 'neighborhood': 'Itambé'},
#  {'count': 2, 'neighborhood': 'Jardim Guanabara'},
#  {'count': 2, 'neighborhood': 'Jardim Iracema'},
#  {'count': 2, 'neighborhood': 'Mata Galinha'},
#  {'count': 2, 'neighborhood': 'P. Potira'},
#  {'count': 2, 'neighborhood': 'Padre Andrade'},
#  {'count': 2, 'neighborhood': 'Parque Araxá'},
#  {'count': 2, 'neighborhood': 'Parque Dois Imrãos'},
#  {'count': 2, 'neighborhood': 'Parque Soledade'},
#  {'count': 2, 'neighborhood': 'Parque dois Irmãos'},
#  {'count': 2, 'neighborhood': 'Patrícia Gomes'},
#  {'count': 2, 'neighborhood': 'Vicente Pinzon'},
#  {'count': 2, 'neighborhood': 'Vila Ellery'},
#  {'count': 1, 'neighborhood': 'ANTONIO BEZERRA'},
#  {'count': 1, 'neighborhood': 'Alvaro Weyne'},
#  {'count': 1, 'neighborhood': 'Antonio Bzerra'},
#  {'count': 1, 'neighborhood': 'Autran Nunes'},
#  {'count': 1, 'neighborhood': 'Açude'},
#  {'count': 1, 'neighborhood': 'Bairro Agua Fria'},
#  {'count': 1, 'neighborhood': 'Bairro de Fátima'},
#  {'count': 1, 'neighborhood': 'Bela Vista'},
#  {'count': 1, 'neighborhood': 'Boa Vista'},
#  {'count': 1, 'neighborhood': 'Cacaru'},
#  {'count': 1, 'neighborhood': 'Cajazeiras'},
#  {'count': 1, 'neighborhood': 'Canindezinho'},
#  {'count': 1, 'neighborhood': 'Castelão'},
#  {'count': 1, 'neighborhood': 'Cidade dos Funcionarios'},
#  {'count': 1, 'neighborhood': 'Coaçu'},
#  {'count': 1, 'neighborhood': 'Condomínio Presidente Castello Branco'},
#  {'count': 1, 'neighborhood': 'Conjunto Nova Metrópole'},
#  {'count': 1, 'neighborhood': 'Conjunto Nova Metrópole V'},
#  {'count': 1, 'neighborhood': 'Cristo Redentor'},
#  {'count': 1, 'neighborhood': 'Cristo Rendentor'},
#  {'count': 1, 'neighborhood': 'Demócrito Rcoha'},
#  {'count': 1, 'neighborhood': 'Dionisio Torres'},
#  {'count': 1, 'neighborhood': 'Distrio Industrial'},
#  {'count': 1, 'neighborhood': 'Farias Brito'},
#  {'count': 1, 'neighborhood': 'Floresta'},
#  {'count': 1, 'neighborhood': 'Fortaleza'},
#  {'count': 1, 'neighborhood': 'Guajiru'},
#  {'count': 1, 'neighborhood': 'Henrique Jorge'},
#  {'count': 1, 'neighborhood': 'JOÃO XXIII'},
#  {'count': 1, 'neighborhood': 'Jereissati I'},
#  {'count': 1, 'neighborhood': 'Jereissati III'},
#  {'count': 1, 'neighborhood': 'José Alencar'},
#  {'count': 1, 'neighborhood': 'Luciano Cavalcante'},
#  {'count': 1, 'neighborhood': 'M'},
#  {'count': 1, 'neighborhood': 'Manuel Sátiro'},
#  {'count': 1, 'neighborhood': 'Monte Castelo'},
#  {'count': 1, 'neighborhood': 'Monteiro'},
#  {'count': 1, 'neighborhood': 'Mucuripe'},
#  {'count': 1, 'neighborhood': 'Nova Metropo'},
#  {'count': 1, 'neighborhood': 'Nova Metropole'},
#  {'count': 1, 'neighborhood': 'Novo Maranguape'},
#  {'count': 1, 'neighborhood': 'PArangaba'},
#  {'count': 1, 'neighborhood': 'PQ. Guadalajara'},
#  {'count': 1, 'neighborhood': 'Panamericano'},
#  {'count': 1, 'neighborhood': 'Parque Genibau'},
#  {'count': 1, 'neighborhood': 'Parque Manibura'},
#  {'count': 1, 'neighborhood': 'Parque Potira'},
#  {'count': 1, 'neighborhood': 'Pefeito José Walter'},
#  {'count': 1, 'neighborhood': 'Perfeito José Walter'},
#  {'count': 1, 'neighborhood': 'Pirambu'},
#  {'count': 1, 'neighborhood': 'Planalto Benjamim'},
#  {'count': 1, 'neighborhood': 'Praia do Futuro'},
#  {'count': 1, 'neighborhood': 'Prefeito Jose Walter'},
#  {'count': 1, 'neighborhood': 'Prefeito José Wlater'},
#  {'count': 1, 'neighborhood': 'Prefeitura José Walter'},
#  {'count': 1, 'neighborhood': 'Presidente Kennedy'},
#  {'count': 1, 'neighborhood': 'Rua O'},
#  {'count': 1, 'neighborhood': 'Salinas'},
#  {'count': 1, 'neighborhood': 'Serinha'},
#  {'count': 1, 'neighborhood': 'Serviluz'},
#  {'count': 1, 'neighborhood': 'São Bento'},
#  {'count': 1, 'neighborhood': 'Vila Cazé'},
#  {'count': 1, 'neighborhood': 'Vila Velha'},
#  {'count': 1, 'neighborhood': 'Vincente Pinzón'},
#  {'count': 1, 'neighborhood': 'centro'},
#  {'count': 1, 'neighborhood': 'itaperi'},
#  {'count': 1, 'neighborhood': 'serrinha'},
#  {'count': 1, 'neighborhood': 'vila União'}]

# %%
sql_query("""
    SELECT COUNT(DISTINCT(value)) AS num_streets
    FROM nodes_tags
    WHERE id IN
    (SELECT id FROM nodes_tags WHERE value = 'Rodolfo Teófilo')
    AND key = 'street' AND type = 'addr'
""")
# Out:
# [{'num_streets': 23}]

# %%
sql_query("""
    SELECT sub1.neighborhood, sub1.num_tags, COUNT(DISTINCT(sub2.value)) AS num_streets
    FROM
    (
        SELECT COUNT(*) as num_tags, value as neighborhood
        FROM (SELECT * FROM nodes_tags WHERE key = 'subur' UNION ALL SELECT * FROM ways_tags WHERE key = 'subur')
        GROUP BY neighborhood
    ) sub1,
    (
        SELECT id FROM nodes_tags WHERE value = sub1.neighborhood AND key = 'street' AND type = 'addr'
    ) sub2
    ORDER BY num_tags DESC
""")
# Out:
# ERROR:root:An unexpected error occurred while tokenizing input
# The following traceback may be corrupted or invalid
# The error message is: ('EOF in multi-line string', (1, 0))
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-68-3918140de074> in <module>()
#      11     ) sub2
#      12     ORDER BY num_tags DESC
# ---> 13 """)
#
# <ipython-input-6-0516c5493890> in sql_query(syntax, output)
#       2 # runs query, then outputs each record as a dict object, by default
#       3 def sql_query(syntax, output=True):
# ----> 4     cur.execute(syntax)
#       5     if output == True:
#       6         pprint.pprint([dict(i) for i in cur.fetchall()])
#
# OperationalError: no such column: sub1.neighborhood
